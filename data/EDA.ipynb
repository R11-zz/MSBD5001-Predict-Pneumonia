# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read Data

# %%
df = pd.read_csv("train.csv")
df
# Out:
#     id  MO HLADR+ MFI (cells/ul)  Neu CD64+MFI (cells/ul)  CD3+T (cells/ul)  \
# 0    0                    3556.0                   2489.0            265.19
# 1    1                    1906.0                    134.0           1442.61
# 2    2                    1586.0                     71.0           1332.74
# 3    3                     683.0                     94.0            419.23
# 4    4                    1032.0                     71.0           1102.72
# ..  ..                       ...                      ...               ...
# 82  82                     626.0                     68.0           1771.57
# 83  83                    1237.0                     71.0           1348.53
# 84  84                     634.0                   1002.0           1300.00
# 85  85                     112.0                    884.0            942.83
# 86  86                     195.0                    213.0            724.00
#
# ...

# %% [markdown]
# ## Label

# %%
df['label'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Attributes
# - Categorical: Sex0M1F
# - Quantitative: the others
#
# *id should be dropped, not important for prediction and analysis*

# %%
df_at = df.drop(['id','label'],axis = 1)
df_at
# Out:
#     MO HLADR+ MFI (cells/ul)  Neu CD64+MFI (cells/ul)  CD3+T (cells/ul)  \
# 0                     3556.0                   2489.0            265.19
# 1                     1906.0                    134.0           1442.61
# 2                     1586.0                     71.0           1332.74
# 3                      683.0                     94.0            419.23
# 4                     1032.0                     71.0           1102.72
# ..                       ...                      ...               ...
# 82                     626.0                     68.0           1771.57
# 83                    1237.0                     71.0           1348.53
# 84                     634.0                   1002.0           1300.00
# 85                     112.0                    884.0            942.83
# 86                     195.0                    213.0            724.00
#
#     CD8+T (cells/ul)  CD4+T (cells/ul)  NK (cells/ul)  CD19+ (cells/ul)  \
# ...

# %%
df_at.isna()
# Out:
#     MO HLADR+ MFI (cells/ul)  Neu CD64+MFI (cells/ul)  CD3+T (cells/ul)  \
# 0                      False                    False             False
# 1                      False                    False             False
# 2                      False                    False             False
# 3                      False                    False             False
# 4                      False                    False             False
# ..                       ...                      ...               ...
# 82                     False                    False             False
# 83                     False                    False             False
# 84                     False                    False             False
# 85                     False                    False             False
# 86                     False                    False             False
#
#     CD8+T (cells/ul)  CD4+T (cells/ul)  NK (cells/ul)  CD19+ (cells/ul)  \
# ...

# %%
# Only 1 row includes NaN, we can drop it in preprocess
df_at[df_at.isna().T.any()]
# Out:
#     MO HLADR+ MFI (cells/ul)  Neu CD64+MFI (cells/ul)  CD3+T (cells/ul)  \
# 39                       NaN                      NaN           1336.54
#
#     CD8+T (cells/ul)  CD4+T (cells/ul)  NK (cells/ul)  CD19+ (cells/ul)  \
# 39            739.71             550.3          68.46            192.07
#
#     CD45+ (cells/ul)  Age  Sex 0M1F  Mono CD64+MFI (cells/ul)
# 39           1615.68   21         0                       NaN

# %%
df_at = df_at.dropna()

# %%
df_at.hist(figsize = (15,15))
plt.show()

# %%
df_at.columns
# Out:
# Index(['MO HLADR+ MFI (cells/ul)', 'Neu CD64+MFI (cells/ul)',
#        'CD3+T (cells/ul)', 'CD8+T (cells/ul)', 'CD4+T (cells/ul)',
#        'NK (cells/ul)', 'CD19+ (cells/ul)', 'CD45+ (cells/ul)', 'Age',
#        'Sex 0M1F', 'Mono CD64+MFI (cells/ul)'],
#       dtype='object')

# %%
plt.figure(figsize=(15,15))
heat = sns.heatmap(data = df_at.corr(), annot=True)
plt.title('Features Correlation Heat Map')
plt.show()
